# %%
# IPA mapping dic

# %%
ipa_dict = {
	"a" : "a",	
	"b" : "b",	
	"c" : "c",	
	"d" : "d",	
	"e" : "e",	
	"f" : "f",	
	"g" : "g",	
	"h" : "h",	
	"i" : "i",	
	"j" : "j",	
	"k" : "k",	
	"l" : "l",	
	"m" : "m",	
	"n" : "n",	
	"o" : "o",	
	"p" : "p",	
	"q" : "q",	
	"r" : "r",	
	"s" : "s",	
	"t" : "t",	
	"u" : "u",	
	"v" : "v",	
	"w" : "w",	
	"x" : "x",	
	"y" : "y",	
	"z" : "z",	
    
	"A" : "A",	
	"B" : "B",	
	"C" : "C",	
	"D" : "D",	
	"E" : "E",	
	"F" : "F",	
	"G" : "G",	
	"H" : "H",	
	"I" : "I",	
	"J" : "J",	
	"K" : "K",	
	"L" : "L",	
	"M" : "M",	
	"N" : "N",	
	"O" : "O",	
	"P" : "P",	
	"Q" : "Q",	
	"R" : "R",	
	"S" : "S",	
	"T" : "T",	
	"U" : "U",	
	"V" : "V",	
	"W" : "W",	
	"X" : "X",	
	"Y" : "Y",	
	"Z" : "Z",	

	"à" : "\\`{a}",	
	"è" : "\\`{e}",	
	"ì" : "\\`{i}",	
	"ò" : "\\`{o}",	
	"ù" : "\\`{u}",	
	"é" : "\\\'{e}",	
	"á" : "\\\'{a}",	
	"ó" : "\\\'{o}",	
	"ú" : "\\\'{u}",	
	"í" : "\\\'{i}",	
	"ś" : "\\\'{s}",	
    
	"ä" : "\\\"{a}",	
	"ü" : "\\\"{u}",	

	"p̅" : "not found",	
	"ḡ" : "\\={g}",	
	"ē" : "\\={e}",	
	"ī" : "\\={i}",	
	"ā" : "\\={a}",	
	"ū" : "\\={u}",	
	"ō" : "\\={o}",	
    
	"ḏ" : "\\b{d}",	
	"ḇ" : "\\b{b}",	
	"ḵ" : "\\b{k}",	
	"ṯ" : "\\b{t}",	
	"ẖ" : "\\b{h}",	
	"ḻ" : "\\b{l}",	
	"ṉ" : "\\b{n}",	
	"ṟ" : "\\b{r}",	
    
	"č" : "\\u{c}",	
	"ě" : "\\u{e}",	
	"š" : "\\u{s}",	
	"ž" : "\\u{z}",	
	"ǰ" : "\\u{j}",	
    
	"ħ" : "\\textcrh ",	
	"ŋ" : "\\engma ",	
    
	"ŏ" : "\\u{o}",	
	"ŭ" : "\\u{u}",	
    
	"ḫ" : "[ not found ]",

	"ǎ" : "\\v{a}",	
	"ǐ" : "\\v{i}",	
	"ǒ" : "\\v{o}",	
	"ǔ" : "\\v{u}",	

	"ǖ" : "\\={\\\"{u}}",	
	"ǘ" : "\\\'{\\\"{u}}",	
	"ǚ" : "\\u{\\\"{u}}",	
	"ǜ" : "\\u{\\\"{u}}",	
    
	"ḍ" : "\\d{d}",	
	"ḥ" : "\\d{h}",	
	"ḳ" : "\\d{k}",	
	"ḷ" : "\\d{l}",	
	"ṇ" : "\\d{n}",	
	"ṛ" : "\\d{r}",	
	"ṣ" : "\\d{s}",	
	"ṭ" : "\\d{t}",	
	"ẓ" : "\\d{z}",	
    
	"ṅ" : "\.{n}",		
    
	"æ" : "\\ae ",	
	"ɑ" : "\\textscripta ",	
	"ɒ" : "\\textturnscripta ",	
	"ɔ" : "\\textopeno ",	
	"ɕ" : "\\textctc ",	
	"ɖ" : "\\textrtaild ",	
    "ð" : "\\eth ",	
	"ə" : "\\textschwa ",	
	"ɚ" : "\\textrhookschwa ",	
	"ɛ" : "\\textepsilon ",	
	"ɝ" : "\\textrhookrevepsilon ",	
	"ɣ" : "\\textbabygamma ",	
	"ɨ" : "\\textbari ",	
	"ɪ" : "\\textsci ",	
	"ɫ" : "\\textltilde ",	
	"ɬ" : "\\textbeltl ",	
	"ɭ" : "\\textrtaill ",	
	"ɲ" : "\\textltailn ",	
	"ɳ" : "\\textrtailn ",	
	"ɴ" : "\\textscn ",	
	"ɸ" : "\\textphi ",	
	"ɹ" : "\\textturnr ",	
	"ɽ" : "\\textrtailr ",	
	"ɾ" : "\\textipa{R}",	
	"ɪ" : "\\textsci ",	
	"ʀ" : "\\textscr ",	
	"ʁ" : "\\textinvscr ",	
	"ʂ" : "\\texttails ",	
	"ʃ" : "\\textesh ",	
	"ʈ" : "\\textrtailt ",	
	"ʊ" : "\\textupsilon ",	
	"ʌ" : "\\textturnv ",	
	"ʍ" : "\\textturnw ",	
	"ʎ" : "\\textturny ",	
	"ʐ" : "\\textrtailz ",	
	"ʒ" : "\\textyogh ",	
	"ʔ" : "\\textglotstop ",	
	"ʕ" : "\\textrevglotstop ",	
	"ʤ" : "\\textdyoghlig ",	
	"ʦ" : "\\texttslig ",	
	"ʧ" : "\\textteshlig ",	
	"ʨ" : "\\texttctclig ",	
	"ʰ" : "\\textsuperscript{h}",	
	"ʱ" : "\\textsuperscript{\\texthth}",	
	"ʲ" : "\\textsuperscript{j}",	
	"ʸ" : "\\textsuperscript{y}",	
	"ʾ" : "\\Alif ",	
	"ʿ" : "\\Ayn ",	
	"ˁ" : " [not found] ",	
	"ç" : " [not found] ",	
	"ñ" : " [not found] ",	
	"þ" : "\\textthorn ",	
	"β" : "\\textbeta ",	
	"θ" : "\\uptheta ",	
	"χ" : "\\textchi ",	
	"ᴅ" : " [not found] ",	
	"ỉ" : " [not found] ",	
	"‘" : " [not found] ",	
	"’" : " [not found] ",	
	"'" : "\\textprimstress ",	
	"ˈ" : "\\textprimstress ",	
	"ˌ" : "\\textsecstress ",	
	"̪" : "\\textsubbridge ",	
	"ɡ" : "\\varg ",	
	"̯"  : "\\textsubarch ",	
	"̃" : "\\textcircumacute ",	
	"ʋ" : "\\textscriptv ",	
	"ː" : "\\textlengthmark  ",	
	"ɦ" : "\\texthth ",	
	"/" : "/",	
	"[" : "[ ",	
	"]" : "] ",	
	"(" : "(",	
	")" : ")",	
	" " : "\ ",	
	"ǁ" : "\\textdoublepipe ",	
	"‖" : "\\textdoublevertline ",	
	"|" : "\\textpipe ",	
	"φ" : "\\textphi ",	
	"!" : "! ",	
	"\n": "\n\n",	
	"." : ".",	
	"," : ","	
}

# %%
def genLaTex(ipa):
    latex = ''
    for g in w:
        try:
            if g not in ipa_dict or 'not' in ipa_dict[g]:
                print('"' + g + '"')
                latex += ' [not found] '
            else:
                latex += ipa_dict[g]
        except KeyError as ke:
            print('"' + g + '"')
    return latex

# %% [markdown]
# # Testing

# %%
words = [
    '/ˌprəʊ.lɪl/ and/or /ˌfi.(ˌ)naɪl/ instead of /ˌproʊ.lɪl/, /ˌfɛ.n(ə)l/',
    '/ˌveɪ.lɪl/ and/or /ˌsɪs.ti.nɪl/ instead of /ˌvæ.lɪl/, /ˌsɪs.ti.i.nɪl/',
    '/ɪkˈsepʃənl/', '/ˈkærəktə rekəɡnɪʃn/', '/ˈkærəktər rekəɡnɪʃn/', '/stjuːˈpɪdəti/', '/stuːˈpɪdəti/', '/ˌsɪəriəl məˈnɒɡəmi/', '/ˈoʊkrə/', "'daŋkə 'frɔɪ̯ndɪn", 'ˈdʒəʋaːɦərˈlaːl ˈneːɦru', '[ˈpriːt̪i ˈzɪɳʈaː]', '/nəˈpoʊliən ˈboʊnəpɑːrt/ [napɔleɔ̃ bɔnɑpaʁt]', 'ˈðɛr']
for w in words:
    print(genLaTex(w))
# Out:
# /\textsecstress pr\textschwa \textupsilon .l\textsci l/\ and/or\ /\textsecstress fi.(\textsecstress )na\textsci l/\ instead\ of\ /\textsecstress pro\textupsilon .l\textsci l/,\ /\textsecstress f\textepsilon .n(\textschwa )l/
# /\textsecstress ve\textsci .l\textsci l/\ and/or\ /\textsecstress s\textsci s.ti.n\textsci l/\ instead\ of\ /\textsecstress v\ae .l\textsci l/,\ /\textsecstress s\textsci s.ti.i.n\textsci l/
# /\textsci k\textprimstress sep\textesh \textschwa nl/
# /\textprimstress k\ae r\textschwa kt\textschwa \ rek\textschwa \varg n\textsci \textesh n/
# /\textprimstress k\ae r\textschwa kt\textschwa r\ rek\textschwa \varg n\textsci \textesh n/
# /stju\textlengthmark  \textprimstress p\textsci d\textschwa ti/
# /stu\textlengthmark  \textprimstress p\textsci d\textschwa ti/
# /\textsecstress s\textsci \textschwa ri\textschwa l\ m\textschwa \textprimstress n\textturnscripta \varg \textschwa mi/
# /\textprimstress o\textupsilon kr\textschwa /
# \textprimstress da\engma k\textschwa \ \textprimstress fr\textopeno \textsci \textsubarch nd\textsci n
# \textprimstress d\textyogh \textschwa \textscriptv a\textlengthmark  \texthth \textschwa r\textprimstress la\textlengthmark  l\ \textprimstress ne\textlengthmark  \texthth ru
# [ \textprimstress pri\textlengthmark  t\textsubbridge i\ \textprimstress z\textsci \textrtailn \textrtailt a\textlengthmark  ]
# /n\textschwa \textprimstress po\textupsilon li\textschwa n\ \textprimstress bo\textupsilon n\textschwa p\textscripta \textlengthmark  rt/\ [ nap\textopeno le\textopeno \textcircumacute \ b\textopeno n\textscripta pa\textinvscr t]
# \textprimstress \eth \textepsilon r

# %%
indian_anthem = '''[dʒənə gəɳə mənə əd̪ʱinɑːjəkə dʒəjə ɦɛː]
[bʱɑːɾət̪ə bʱɑːgjə ʋɪdʱɑːt̪ɑː ǁ]
[pə̃dʒɑːbə sɪnd̪ʱu gʊdʒəɾɑːt̪ə məɾɑːʈʰɑː |]
[d̪ɾɑːʋɪɽə ʊt̪kələ bə̃gə]
[ʋɪ̃d̪ʱjə ɦɪmɑːcələ jəmʊnɑː gə̃gɑː |]
[ʊttʃʰələ dʒələd̪ʱi t̪əɾə̃gə]
[t̪əbə ʃʊbʱə nɑːmeː dʒɑːgeː | t̪əbə ʃʊbʱə ɑːʃɪʂə mɑ̃ːgeː]
[gɑːɦeː t̪əbə dʒəjə gɑːt̪ʰɑː ‖]
[dʒənə gəɳə mə̃gələ d̪ɑːjəkə dʒəjə ɦɛː |]
[bʱɑːɾət̪ə bʱɑːgjə ʋɪd̪ʱɑːt̪ɑː ‖]
[dʒəjə ɦɛː | dʒəjə ɦɛː | dʒəjə ɦɛː |]
[dʒəjə dʒəjə dʒəjə dʒəjə ɦɛː ‖]'''
tamil_anthem = '''
[ Nīrāruṅ kaṭaluṭutta nilamaṭantaik keḻiloḻukum ]
[ cīrārum vataṉameṉat tikaḻ kumari kaṇṭamitil ]
[ tekkaṇamum atiṟciṟanta tamilar nal tirunāṭum ]
[ takkaciṟu piṟainutalum tarittanaṟun tilakamumē ]
[ attilaka vācaṉaipōl aṉaittulakum iṉpamuṟa ]
[ etticaiyum pukaḻmaṇakka iruntaperun tamiḻaṇaṅkē! ]
[ palluyirum palavulakum paṭaittaḷittu tuṭaikkiṉumōr ]
[ ellaiyaṟu paramporuḷmuṉ iruntapaṭi iruppatupōl ]
[ kaṉṉaṭamuṅ kaḷiteluṅkum kaviṉmalaiyāḷamum tuḷuvum ]
[ uṉṉutarat tēyutittē oṉṟupala vākiṭiṉum ]
[ āriyampōl ulakavaḻakkaḻin toḻintu citaiyāvuṉ ]
[ uṉ cīriḷamait tiṟamviyantu ]
[ ceyalmaṟantu vāḻttutumē! ]
[ vāḻttutumē!! ]
[ vāḻttutumē!!! ]'''

# %%
latex = ''
for c in tamil_anthem:
    try:
        if 'not' in ipa_dict[c]:
            print(c)
        latex += ipa_dict[c]
        #if c == ']':
        #    latex += '\\'
    except KeyError as ke:
        print('"' + c + '"')
print(latex)
# Out:
# [ \ N\={i}r\={a}ru\.{n}\ ka\d{t}alu\d{t}utta\ nilama\d{t}antaik\ ke\b{l}ilo\b{l}ukum\ ]
#
# [ \ c\={i}r\={a}rum\ vata\b{n}ame\b{n}at\ tika\b{l}\ kumari\ ka\d{n}\d{t}amitil\ ]
#
# [ \ tekka\d{n}amum\ ati\b{r}ci\b{r}anta\ tamilar\ nal\ tirun\={a}\d{t}um\ ]
#
# [ \ takkaci\b{r}u\ pi\b{r}ainutalum\ tarittana\b{r}un\ tilakamum\={e}\ ]
#
# [ \ attilaka\ v\={a}ca\b{n}aip\={o}l\ a\b{n}aittulakum\ i\b{n}pamu\b{r}a\ ]
#
# [ \ etticaiyum\ puka\b{l}ma\d{n}akka\ iruntaperun\ tami\b{l}a\d{n}a\.{n}k\={e}! \ ]
#
# [ \ palluyirum\ palavulakum\ pa\d{t}aitta\d{l}ittu\ tu\d{t}aikki\b{n}um\={o}r\ ]
#
# [ \ ellaiya\b{r}u\ paramporu\d{l}mu\b{n}\ iruntapa\d{t}i\ iruppatup\={o}l\ ]
#
# [ \ ka\b{n}\b{n}a\d{t}amu\.{n}\ ka\d{l}itelu\.{n}kum\ kavi\b{n}malaiy\={a}\d{l}amum\ tu\d{l}uvum\ ]
#
# [ \ u\b{n}\b{n}utarat\ t\={e}yutitt\={e}\ o\b{n}\b{r}upala\ v\={a}ki\d{t}i\b{n}um\ ]
#
# [ \ \={a}riyamp\={o}l\ ulakava\b{l}akka\b{l}in\ to\b{l}intu\ citaiy\={a}vu\b{n}\ ]
#
# [ \ u\b{n}\ c\={i}ri\d{l}amait\ ti\b{r}amviyantu\ ]
#
# [ \ ceyalma\b{r}antu\ v\={a}\b{l}ttutum\={e}! \ ]
#
# [ \ v\={a}\b{l}ttutum\={e}! ! \ ]
#
# [ \ v\={a}\b{l}ttutum\={e}! ! ! \ ]

# %% [markdown]
# # IPA not in dictionay

# %%
for key in ipa_dict:
    if 'not' in ipa_dict[key]:
        print(key)
# Out:
# p̅
# ð
# ˁ
# ç
# ñ
# θ
# ᴅ
# ỉ
# ‘
# ’
